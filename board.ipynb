# %%
from utils.analytics import load_tensorboard_logs

# %%
train_results_df = load_tensorboard_logs(log_dir="tb_logs/rnn")

# %%
train_results_df = train_results_df.sort_values(
    by=["val_acc"], ascending=False
).reset_index(drop=True)
train_results_df
# Out:
#       val_acc  batch_size  hidden_dim  learning_rate optimizer_name  \
# 0    0.863119          32         256        0.00100        RMSprop
# 1    0.854884          32         256        0.01000        Adagrad
# 2    0.845900          32         256        0.01000        Adagrad
# 3    0.830054          64         256        0.01000        Adagrad
# 4    0.823873          32         256        0.00100        RMSprop
# ..        ...         ...         ...            ...            ...
# 227  0.151852          64         256        0.00001            SGD
# 228  0.146278         256         256        0.00001            SGD
# 229  0.144659        2048         256        0.00001            SGD
# 230  0.144149         512         256        0.00001            SGD
# 231  0.142701        1024         256        0.00001            SGD
#
#      train_loss  train_acc  num_layers sentence_representation_type  freeze  \
# 0      0.015387   1.000000           1                          max   False
# 1      0.013205   1.000000           1                          max   False
# 2      0.100842   0.833333           1                      average   False
# 3      0.021949   1.000000           1                          max   False
# 4      0.148134   0.950000           1                      average   False
# ..          ...        ...         ...                          ...     ...
# 227    1.796444   0.163889           1                         last   False
# 228    1.811428   0.150338           1                          max   False
# 229    1.810742   0.164018           1                          max   False
# 230    1.805212   0.159848           1                          max   False
# 231    1.812097   0.166747           1                          max   False
#
#      epoch  val_loss                                           filename
# 0      7.0  0.420632  events.out.tfevents.1762166875.ArchThinkpadT14...
# 1      7.0  0.453627  events.out.tfevents.1762156840.ArchThinkpadT14...
# 2      7.0  0.574166  events.out.tfevents.1762156763.ArchThinkpadT14...
# 3      6.0  0.420415  events.out.tfevents.1762158519.ArchThinkpadT14...
# 4      6.0  0.618236  events.out.tfevents.1762166797.ArchThinkpadT14...
# ..     ...       ...                                                ...
# 227   17.0  1.804176  events.out.tfevents.1762145639.ArchThinkpadT14...
# 228   45.0  1.822618  events.out.tfevents.1762148933.ArchThinkpadT14...
# 229    3.0  1.825725  events.out.tfevents.1762152536.ArchThinkpadT14...
# 230   19.0  1.825076  events.out.tfevents.1762150277.ArchThinkpadT14...
# 231    3.0  1.825693  events.out.tfevents.1762151393.ArchThinkpadT14...
#
# [232 rows x 13 columns]
